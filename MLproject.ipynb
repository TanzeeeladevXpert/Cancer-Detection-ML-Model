# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv('/content/Cancer_Data.csv')

# %%
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dataset.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df=dataset.drop(dataset.columns[32],axis=1)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
X=df.drop(df.columns[1],axis=1)
y=df['diagnosis']

# %%
X
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,shuffle=True)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train=torch.tensor(x_train,dtype=torch.float32)
X_text=torch.tensor(x_test,dtype=torch.float32)

# %%
# Map 'M' to 1 and 'B' to 0 for numerical conversion
y_train = y_train.map({'M': 1, 'B': 0})
y_test = y_test.map({'M': 1, 'B': 0})
y_train = torch.tensor(y_train.values, dtype=torch.float32).reshape(-1, 1)
y_test = torch.tensor(y_test.values, dtype=torch.float32).reshape(-1, 1)

# %%
model=nn.Sequential(
    nn.Linear(31,20),
    nn.ReLU(),
    nn.Linear(20,10),
    nn.ReLU(),
    nn.Linear(10,1),
    nn.Sigmoid()
)

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=31, out_features=20, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=20, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
optimizer=optim.Adam(model.parameters(),lr=0.01)
loss_fn=nn.BCELoss()

# %%
batch_size=10
num_epochs=10
num_batches=len(x_train)//batch_size

# %%
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0

    for i in range(0, len(x_train), batch_size):
        xb = x_train[i:i+batch_size]
        yb = y_train[i:i+batch_size]

        optimizer.zero_grad()
        outputs = model(xb)
        loss = loss_fn(outputs, yb)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss/num_batches:.4f}")
# Out:
# Epoch [1/10], Loss: 0.0031
# Epoch [2/10], Loss: 0.0023
# Epoch [3/10], Loss: 0.0013
# Epoch [4/10], Loss: 0.0009
# Epoch [5/10], Loss: 0.0006
# Epoch [6/10], Loss: 0.0006
# Epoch [7/10], Loss: 0.0004
# Epoch [8/10], Loss: 0.0004
# Epoch [9/10], Loss: 0.0003
# Epoch [10/10], Loss: 0.0003

# %%
model.eval()
with torch.no_grad():
    predictions = model(X_text)
    predictions = (predictions >= 0.5).float()
    correct = (predictions == y_test).sum()
    accuracy = correct / y_test.shape[0]

print("Test Accuracy:", accuracy.item())
# Out:
# Test Accuracy: 0.9707602262496948

# %%
new_data = torch.tensor([[17.9, 10.3, 122.8, 1001, 0.118,0.27, 0.30, 0.14, 0.24, 0.07,0.15, 0.18, 1.0, 25.3, 0.005,
0.02, 0.03, 0.01, 0.02, 0.003,20.1, 15.0, 130.0, 1200,0.14, 0.20, 0.25, 0.12,0.30, 0.08, 0.10]],dtype=torch.float32)
model.eval()

with torch.no_grad():
    output = model(new_data)
    prediction = (output >= 0.5).float()

# Result
if prediction.item() == 1:
    print("Prediction: Cancer Detected")
else:
    print("Prediction: No Cancer Detected")
# Out:
# Prediction: Cancer Detected

# %%
plt.figure()
plt.bar(["Test Accuracy"], [accuracy.item()])
plt.ylabel("Accuracy")
plt.title("Final Model Accuracy")
plt.show()
